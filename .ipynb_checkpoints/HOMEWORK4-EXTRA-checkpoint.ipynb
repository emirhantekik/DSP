# %% [markdown]
# # ÖDEV1 veya ÖDEV1_EK <--yazılacaktır
#
# ### Dokümanın adı ODEV1_OgrenciKOD.ipynb  olmalıdır.
# ### EK problemler için dosya adı  ODEV1_EK_OgrenciKOD.ipynb  olmalıdır.
#
# #### Toplam 2 adet ipynb uzantılı dosya yüklenecektir.
#
# ### Dosyaları sıkıştırıp yükleMEyiniz, olduğu gibi yükleyiniz.

# %% [markdown]
# ## Soru-2

# %% [markdown]
# ## H(z) el ile hesaplanması

# %% [markdown]
# $ H(z) = \frac{z^2}{(z+1)(z-1)^2} = \frac{A}{z+1} + \frac{B}{z-1} + \frac{C}{(z-1)^2} $
#
# #### A için:
# $ H(z)*(z+1)|_{z = -1} = \frac{z^2}{(z-1)^2}|_{z = -1}$
#
# $A= \frac{1}{4} $
# #### C için:
# $ H(z)*(z-1)^2|_{z = 1} = \frac{z^2}{(z+1)}|_{z = 1}$
#
# $C= \frac{1}{2} $
# #### B için:
# Payda eşitlenilir ve A ve C yerine yazılarak B bulunur.
#
# ${z^2}=A{(z-1)^2} + B{(z-1)*(z+1)} + C $
#
# $B = \frac{3}{4} $
#
# # H(z) son hali:
# #### $ H(z) = \frac{z^2}{(z+1)(z-1)^2} = \frac{\frac{1}{4}}{z+1} + \frac{\frac{3}{4}}{z-1} + \frac{\frac{1}{2}}{(z-1)^2} = H_1(z) +  H_2(z) +  H_3(z) $
#
# ### $ H_1(z) = \frac{\frac{1}{4}}{z+1} =\frac{1}{4} z^{-1}\frac{z}{z+1}\Rightarrow h_1[n] = \frac{1}{4}(-1)^{n-1}u[n-1]$
#
# ### $ H_2(z) = \frac{\frac{3}{4}}{z-1} =\frac{3}{4} z^{-1}\frac{z}{z-1}\Rightarrow h_2[n] = \frac{3}{4}(1)^{n-1}u[n-1] $
#
# ### $ H_3(z) = \frac{\frac{1}{2}}{(z-1)^2} =\frac{1}{2} z^{-2}\frac{z^2}{(z-1)^2}\Rightarrow h_3[n] = \frac{1}{2} (n-1)(1)^{n-1}u[n-1]$

# %% [markdown]
# ## Örnek 7'ye uyarlama

# %%
def u(n):
    return 1 * (n >= 0)

# %%
import math
import warnings
z = np.array([0, 0]) # a zero @z=0
p = np.array([-1, 1, 1]) # poles of the system
b, a = sgnl.zpk2tf(z, p, 1) # since there is no gain k=1
b,a
# we do the partial fraction expansion by:
r, p, k = sgnl.residuez(b,a) #
r,p,k
# Out:
# (array([0.25-0.j, 0.5 +0.j, 0.25+0.j]),
#  array([ 1.+0.j,  1.+0.j, -1.+0.j]),
#  array([], dtype=float64))

# %%
import math
print(r)
print(p)
print(k)
poless = np.roots(a)

n = np.linspace(0,20,21)

x = np.zeros(len(n))
for i in range(1,len(n)):
    x[i] = (1/4)*(math.pow(-1,(n[i-1]))*u(n[i-1])) + (3/4)*u(n[i-1]) + (1/2)*((n[i-1]))*u((n[i-1]))
    
plt.figure()
plt.stem(n,x)
plt.xlabel("n")
plt.title("h[n]");
# Out:
# [0.25-0.j 0.5 +0.j 0.25+0.j]
# [ 1.+0.j  1.+0.j -1.+0.j]
# []
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Örnek 8'e uyarlama

# %%
# import the necessary libraries
import numpy as np # for using basic array functions
import matplotlib.pyplot as plt # for this example, it may not be necessary
# the main package for signal processing is called "scipy" and we will use "signal"
import scipy.signal as sgnl
# alternative syntax: from scipy import signal as sgnl
# %matplotlib notebook

# %%
num   = np.array([0,  1, 0, 0]) 
denum = np.array([1, -1, -1, 1]) # payda : 1-z-z^2+z^3
n, x = sgnl.dimpulse((num, denum, 1), n=21)

#print(x)
fig = plt.figure()
plt.stem(n, np.squeeze(x))
plt.xlabel("n")
plt.title("h[n]")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'h[n]')

# %% [markdown]
# ## Örnek 9'a göre

# %%
# ÖRNEK 7 için kodlar
n = np.linspace(0,20,21)
x = np.zeros(len(n))
for i in range(1,len(n)):
    x[i] = (1/4)*(math.pow(-1,(n[i-1]))*u(n[i-1])) + (3/4)*u(n[i-1]) + (1/2)*((n[i-1]))*u((n[i-1]))
    
    
# ÖRNEK 8 için kodlar
num   = np.array([0,  1, 0, 0])
denum = np.array([1, -1, -1, 1]) # payda : 1-z-z^2+z^3
n8, x8 = sgnl.dimpulse((num, denum, 1), n=21)

fig = plt.figure();
plt.subplot(1,2,1)
plt.stem(n, x)
plt.xlabel("n")
plt.ylabel("h[n]")
plt.title(" Örnek 7'ye göre")

plt.subplot(1,2,2)
plt.stem(n8, np.squeeze(x8))
plt.xlabel("n")
plt.ylabel("h[n]")
plt.title(" Örnek 8'e göre");
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Örnek 7 ve Örnek 8'te sistem fonksiyonu için katsayılar aynıyken bazı farklar bulunmaktadır. İlk olarak H(z)'nin el ile sıfırları,kutupları,num,denum değerleri bulunmuştur. Yukarıda Örnek çalışma 9'da örnek çalışma 7 ve örnek çalışma 8 grafikleri aynı bulunmuştur.

# %% [markdown]
# # SORU-3

# %% [markdown]
# # Dürtü cevabının el ile bulunması:
# $ H(z) = \frac{1 + 3z^{-1} + \frac{11}{6}z^{-2} + \frac{1}{3}z^{-3} }{1 + \frac{5}{6}z^{-1} + \frac{1}{6}z^{-2} } $ sistem fonksiyonu için en uygun ters z-transform işlemi,basit kesirlerine ayrılarak elde edilecektir. polinom bölmesinde bölüm ve kalan çıkacaktır.
#
# $H(Z)= 2*z^-1 +1 + \frac {(1/6)*z^-1} {1+5/6*z^-1+(1/6)*z^-2} $
#
# $ H(z) = 2z^{-1} + 1 + \frac{1}{1 + \frac{1}{3}z^{-1}} + \frac{1}{1 + \frac{1}{2}z^{-1}} \Rightarrow$
# $ h[n] = 2 \delta [n-1] + \delta [n] + (\frac{-1}{3})^n u[n] - (\frac{-1}{2})^n u[n]$

# %% [markdown]
# ## Örnek Çalışma 7'ye uyarlama

# %%
import numpy as np

a = [1, 3, 11/6, 1/3] # paydaki katsayılar
roots = np.roots(a) # kökleri hesapla
print(roots)
# Out:
# [-2.25147697+0.j         -0.37426152+0.08932682j -0.37426152-0.08932682j]

# %%
z = np.array([-2.251491,(-0.3742-0.089321j),(-0.3742+0.089321j)]) 
p = np.array([-1/2, -1/3])
b, a = sgnl.zpk2tf(z, p, 1)
b,a

r, p, k = sgnl.residuez(b,a) 
print(r)
print(p)
print(k)

poless = np.roots(a)
# Out:
# [ 0.99937851 -1.0006148 ]
# [-0.33333333 -0.5       ]
# [1.00123629 1.99937644]

# %%
def dirac(m):
    if m == 0:
        return 1
    else:
        return 0
    
n=np.arange(0,20,1)
x=np.zeros(len(n))
for k in range(len(n)):
    x[k]=2*dirac(n[k]-1)+dirac(n[k])+(-0.96075)*math.pow(-1/2,(n[k]))*u(n[k]) + (0.88)*u(n[k])*math.pow(-1/3,(n[k]))
plt.figure()
plt.stem(n,x)
plt.xlabel("n")
plt.ylabel("h[n]")
plt.title("Sistemin örnek çalışma 7'ye Göre Dürtü Cevabı")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, "Sistemin örnek çalışma 7'ye Göre Dürtü Cevabı")

# %% [markdown]
# ## Örnek Çalışma 8'ye uyarlama

# %%
num = np.array([1,3,11/6,1/3]) 
denum = np.array([1,5/6,1/6,0])
n, x = sgnl.dimpulse((num, denum, 1), n=20)
plt.figure()
plt.stem(n,np.squeeze(x))
plt.xlabel("n")
plt.ylabel("h[n]")
plt.title(" Örnek çalışma 8'e göre Uyarlama");
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Örnek çalışma 9'a göre uyarlama

# %%
n = np.linspace(0,20,21)
x = np.zeros(len(n))

for k in range(len(n)):
    x[k]=2*dirac(n[k]-1)+dirac(n[k])+(-1)*math.pow(-1/2,(n[k]))*u(n[k]) + (1)*u(n[k])*math.pow(-1/3,(n[k]))

num = np.array([1,3,11/6,1/3]) 
denum = np.array([1,5/6,1/6,0]) # coeffs of denum
n8, x8 = sgnl.dimpulse((num, denum, 1), n=20)

fig = plt.figure(figsize=(8,6))
plt.subplot(1,2,1)
plt.stem(n, x)
plt.ylabel('$h_{7}[n]$')
plt.subplot(1,2,2)
plt.stem(n8, np.squeeze(x8))
plt.ylabel('$h_{8}[n]$');
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### Örnek çalışma 7 ve örnej çalışma 8'e göre yapılan hesaplamalarda grafikler aynı bulunmuştur.

# %% [markdown]
# # SORU-4

# %% [markdown]
# $ H(Z)= \frac {10*(1-(\frac{1} {\sqrt(2)} {z^{-1]} )} {(1-e^{(j*\pi/4)*z^{-1}})*(1-e^{(-j*\pi/4)*z^{-1}})* (1-0.5*z^{-1}} $
#
# $ Basit Kesirlere Ayırma Uygulanırsa:$
#
# $ H(Z)= \frac {A} {(1-e^{(j*\pi/4)*z^{-1}})} + \frac {B} {(1-e^{(-j*\pi/4)}*z^{-1})} + \frac {C} {(1-0.5 z^{-1})*z^{-1}} $
#
# A için:
#
# $ A =5.960-3.256J$
#
# B için:
#
# $ B=5.960+3.256J$
#
# C için:
#
# $ C=-1.90$
#
# bulunmaktadır.

# %% [markdown]
# ## Örnek çalışma 7'ye göre uyarlama

# %%
import numpy as np

# katsayılar
a = [10, -10*np.sqrt(1/2), 0]

# kökleri hesapla
roots = np.roots(a)

print(roots)
# Out:
# [0.70710678 0.        ]

# %%
z = np.array([0.707])
p1 = 1/2
p2 = 0.707 + 0.707j
p3 = 0.707 - 0.707j
p = np.array([p1, p2, p3])
b, a = sgnl.zpk2tf(z, p, 10)

r, p, k = sgnl.residuez(b,a) 
print(r)
print(p)
print(k)

poless = np.roots(a)
# Out:
# [-1.90713804+0.j          5.95356902-3.25687583j  5.95356902+3.25687583j]
# [0.5  +0.j    0.707+0.707j 0.707-0.707j]
# []

# %%
import warnings
warnings.simplefilter("ignore")

n = np.linspace(0,20,21)
x = np.zeros(len(n))
exp = np.exp

for k in range(len(n)):
    x[k]=(5.9535 - 3.2568j)*(exp(1j*np.pi*n[k]/4))*u(n[k]) + (5.9535 + 3.2568j)*exp(-1j*np.pi*n[k]/4)*u(n[k]) + (-1.9071)*((math.pow(1/2,n[k]))*u(n[k])) 

## kökler karmaşık sayı bulunduğundan kaynaklı faz ve genlik grafiği farklı grafiklerde çizdirildi. abs ve angle fonksiyonları
## kullanıldı.
    
fig = plt.figure(figsize = (8,6))
plt.subplot(1,2,1), plt.stem(n, np.abs(x))
plt.xlabel("n")
plt.ylabel("|h[n]|")
plt.title(" genlik")
plt.subplot(1,2,2), plt.stem(n, np.angle(x))
plt.xlabel("n")
plt.ylabel('$\\measuredangle h[n]$')
plt.title("faz");
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## Örnek çalışma 8'e uyarlama

# %%
num = np.array([10, -7.071, 0, 0]) 
denum = np.array([1, -1.914, 1.707, -0.5])
n, x = sgnl.dimpulse((num, denum, 1),n=21)
fig = plt.figure(figsize=(8,6))
plt.subplot(1,2,1), plt.stem(n, np.squeeze(np.abs(x)))
plt.xlabel("n")
plt.ylabel("|h[n]|")
plt.title(" Genlik")
plt.subplot(1,2,2), plt.stem(n, np.squeeze(np.angle(x)))
plt.xlabel("n")
plt.ylabel('$\\measuredangle h[n]$')
plt.title("Faz")
# Out:
# <img src="data:image/png;base64,..." width="800">
# Text(0.5, 1.0, 'Faz')

# %% [markdown]
# ## Örnek Çalışma 9'a göre uyarlama

# %%
# Örnek 7 
n = np.linspace(0,20,21)
x = np.zeros(len(n))
pi = np.pi
exp = np.exp

for k in range(len(n)):
    x[k]=(5.9535 - 3.2568j)*(exp(1j*pi*n[k]/4))*u(n[k]) + (5.9535 + 3.2568j)*exp(-1j*pi*n[k]/4)*u(n[k]) + (-1.9071)*((math.pow(1/2,n[k]))*u(n[k])) 

fig = plt.figure(figsize = (8,6))
plt.subplot(2,2,1), plt.stem(n, np.abs(x))
plt.xlabel("n")
plt.ylabel("|h[n]|")
plt.title(" Genlik")
plt.subplot(2,2,2), plt.stem(n, np.angle(x))
plt.xlabel("n")
plt.ylabel('$\\measuredangle h[n]$')
plt.title("Faz")


num = np.array([10, -7.071, 0, 0])  #10 7.071
denum = np.array([1, -1.914, 1.707, -0.5]) # coeffs of denum
n8, x8 = sgnl.dimpulse((num, denum, 1), n=21)
plt.subplot(2,2,3), plt.stem(n8, np.squeeze(np.abs(x8)))
plt.xlabel("n")
plt.ylabel("|h[n]|")

plt.subplot(2,2,4), plt.stem(n8, np.squeeze(np.angle(x8)))
plt.xlabel("n")
plt.ylabel('$\\measuredangle h[n]$');
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# # SORU-5

# %% [markdown]
# Z dönüşümünün ne olduğunu,z dönüşümünün özellikleri, Z dönüşüm ile işaretin kararlılık ve nedenselliği öğrenmeyi, ROC'un özellikleri, Z dönüşümü yaparken ROC'un önemini öğrendim.
#
# Pythonda Ters z dönüşümleri yöntemlerinden gözlem ile, basit kesirlere ayırma ile ve kuvvet serisi açılımı ile gerçekleştirip zaman domainine örneğin H(z)-> h[n] , X(z)-> x[n] işlem gerçekleştirmeyi öğrendim. Z dönüşümlerini el ile pratiğini yaparak kavramış oldum.
